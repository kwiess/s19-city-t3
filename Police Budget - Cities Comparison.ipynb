# %%
import pandas as pd
from pandas import DataFrame, Series
import requests, json
import sqlite3
import math
# %matplotlib inline
import matplotlib

#link to populations: https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population
#found the budgets on each cities website
cities_s = pd.Series({'Madison, WI': 69.789912, 'Reno, NV': 65.538036, 'Chandler, AZ': 85.717408, 'St. Petersburg, FL': 85.717408})
cities_s.plot.bar(figsize = (7,7), title = "Comparison of Police Budgets Among Cities", color = "blue")
matplotlib.pyplot.ylabel('Budget (Millions)')
matplotlib.pyplot.xlabel('Cities')
None
